# %% [markdown]
# ## Import Librares

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Loading Dataset

# %%
data=pd.read_csv(r"C:\Users\sujat\Downloads\DataSets\Houseprice_by_City (1).csv")
data
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                  City  LONGITUDE   LATITUDE  \
# ...

# %% [markdown]
# ### Preprocessing Part

# %%
data.isnull().sum()
# Out:
# POSTED_BY                0
# UNDER_CONSTRUCTION       0
# RERA                     0
# BHK_NO.                  0
# BHK_OR_RK                0
# SQUARE_FT                0
# READY_TO_MOVE            0
# RESALE                   0
# City                     9
# LONGITUDE                0
# LATITUDE                 0
# TARGET(PRICE_IN_LACS)    0
# dtype: int64

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# # 1) How to setup 2 precisions for Square Feet.

# %%
data["SQUARE_FT"].round(2)
# Out:
# 0        1300.24
# 1        1275.00
# 2         933.16
# 3         929.92
# 4         999.01
#           ...
# 29446    2500.00
# 29447     769.23
# 29448    1022.64
# 29449     927.08
# 29450     896.77
# Name: SQUARE_FT, Length: 29451, dtype: float64

# %% [markdown]
# # 2) Slice the cities and find the benglores rera approved flates.

# %%
data
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                  City  LONGITUDE   LATITUDE  \
# ...

# %%
data["City"].unique()
# Out:
# array(['Bangalore', 'Mysore', 'Ghaziabad', 'Kolkata', 'Kochi', 'Jaipur',
#        'Mohali', 'Chennai', 'Siliguri', 'Noida', 'Raigad', 'Bhubaneswar',
#        'Wardha', 'Pune', 'Mumbai', 'Nagpur', 'Deoghar', 'Bhiwadi',
#        'Faridabad', 'Lalitpur', 'Maharashtra', 'Vadodara',
#        'Visakhapatnam', 'Vapi', 'Mangalore', 'Aurangabad', 'Ottapalam',
#        'Vijayawada', 'Belgaum', 'Bhopal', 'Lucknow', 'Kanpur',
#        'Gandhinagar', 'Pondicherry', 'Agra', 'Ranchi', 'Gurgaon', 'Udupi',
#        'Indore', 'Jodhpur', 'Coimbatore', 'Valsad', 'Palghar', 'Surat',
#        'Varanasi', 'Guwahati', 'Amravati', 'Anand', 'Tirupati',
#        'Secunderabad', 'Raipur', 'Vizianagaram', 'Thrissur', 'Satna',
#        'Madurai', 'Chandigarh', 'Shimla', 'Gwalior', 'Rajkot', 'Sonipat',
#        'Allahabad', 'Berhampur', 'C V Raman Nagar', ' Mahalaxmi 2',
#        'Roorkee', 'Dharuhera', 'Latur', 'Durgapur', 'Panchkula',
#        'Solapur', 'Durg', 'Goa', 'Jamshedpur', 'Hazaribagh', 'Jabalpur',
# ...

# %%
data1=data.iloc[:,[2,8]]
data1
# Out:
#        RERA                  City
# 0         0             Bangalore
# 1         0                Mysore
# 2         0             Bangalore
# 3         1             Ghaziabad
# 4         0               Kolkata
# ...     ...                   ...
# 29446     0                  Agra
# 29447     0   Lake View Recidency
# 29448     0                Jaipur
# 29449     0               Chennai
# 29450     1                Jaipur
#
# [29451 rows x 2 columns]

# %%
data2=data1.loc[(data1["RERA"]==1)&(data1["City"]=="Bangalore")]
data2
# Out:
#        RERA       City
# 8         1  Bangalore
# 17        1  Bangalore
# 19        1  Bangalore
# 163       1  Bangalore
# 180       1  Bangalore
# ...     ...        ...
# 29369     1  Bangalore
# 29386     1  Bangalore
# 29402     1  Bangalore
# 29404     1  Bangalore
# 29436     1  Bangalore
#
# [1147 rows x 2 columns]

# %%
data2["RERA"].unique()
# Out:
# array([1], dtype=int64)

# %%
data2["City"].unique()
# Out:
# array(['Bangalore'], dtype=object)

# %% [markdown]
# # 3) Rename the City cols with ADDRESS Name .

# %%
data
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                  City  LONGITUDE   LATITUDE  \
# ...

# %%
data1=data.rename(columns={"City":"ADDRESS"})
data1
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE               ADDRESS  LONGITUDE   LATITUDE  \
# ...

# %% [markdown]
# # 4) Increses the Target price of all the flats with 10 lac and reduce the Banglores flate rates with 5 Lac.

# %%
data
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                  City  LONGITUDE   LATITUDE  \
# ...

# %%
data1=data.iloc[:,[8,11]]
data1
# Out:
#                        City  TARGET(PRICE_IN_LACS)
# 0                 Bangalore                   55.0
# 1                    Mysore                   51.0
# 2                 Bangalore                   43.0
# 3                 Ghaziabad                   62.5
# 4                   Kolkata                   60.5
# ...                     ...                    ...
# 29446                  Agra                   45.0
# 29447   Lake View Recidency                   16.0
# 29448                Jaipur                   27.1
# 29449               Chennai                   67.0
# 29450                Jaipur                   27.8
#
# [29451 rows x 2 columns]

# %%
New_price=[]
for x in data1["TARGET(PRICE_IN_LACS)"]:
   x1=x+10
   New_price.append(x1)
print(New_price)
# Out:
# [65.0, 61.0, 53.0, 72.5, 70.5, 52.0, 76.5, 62.0, 51.6, 46.0, 45.0, 120.0, 58.0, 72.0, 30.0, 81.1, 95.0, 190.0, 32.0, 130.0, 55.0, 52.0, 65.0, 310.0, 60.0, 37.5, 56.0, 32.9, 49.0, 22.5, 62.0, 43.0, 65.0, 92.0, 250.0, 65.0, 75.0, 75.0, 45.0, 85.0, 9120.0, 75.0, 40.0, 260.0, 230.0, 48.0, 70.0, 56.0, 36.3, 61.6, 65.0, 81.9, 140.0, 42.5, 49.9, 69.9, 75.0, 120.0, 78.5, 109.0, 260.0, 37.5, 80.0, 60.0, 80.0, 32.1, 290.0, 84.0, 95.0, 59.2, 55.0, 70.0, 40.0, 43.0, 39.0, 220.0, 98.6, 790.0, 40.0, 150.0, 250.0, 170.0, 110.0, 70.0, 91.5, 44.0, 41.8, 40.0, 34.9, 58.0, 63.7, 52.0, 160.0, 450.0, 150.0, 68.0, 110.0, 28.0, 70.4, 40.0, 60.0, 150.0, 90.0, 59.0, 34.5, 28.0, 105.0, 32.0, 58.0, 85.0, 103.0, 98.0, 92.0, 85.0, 31.2, 74.9, 90.0, 84.0, 109.0, 52.0, 350.0, 80.0, 48.0, 480.0, 56.0, 93.7, 92.0, 80.0, 21.0, 58.0, 250.0, 340.0, 110.0, 72.0, 26.5, 310.0, 110.0, 58.0, 24.5, 110.0, 75.0, 35.0, 48.0, 47.0, 67.9, 190.0, 190.0, 30.0, 95.0, 160.0, 43.9, 98.0, 35.0, 110.0, 109.0, 77.0, 220.0, 59.0, 85.0, 6
# ...

# %%
data1.insert(1,"New_price",New_price)

# %%
del data1["TARGET(PRICE_IN_LACS)"]

# %%
data1
# Out:
#                        City  New_price
# 0                 Bangalore       65.0
# 1                    Mysore       61.0
# 2                 Bangalore       53.0
# 3                 Ghaziabad       72.5
# 4                   Kolkata       70.5
# ...                     ...        ...
# 29446                  Agra       55.0
# 29447   Lake View Recidency       26.0
# 29448                Jaipur       37.1
# 29449               Chennai       77.0
# 29450                Jaipur       37.8
#
# [29451 rows x 2 columns]

# %%
data2=data1.loc[(data1["City"]=="Bangalore")]
data2
# Out:
#             City  New_price
# 0      Bangalore       65.0
# 2      Bangalore       53.0
# 8      Bangalore       51.6
# 11     Bangalore      120.0
# 12     Bangalore       58.0
# ...          ...        ...
# 29408  Bangalore       52.0
# 29415  Bangalore      230.0
# 29421  Bangalore      107.0
# 29433  Bangalore       60.0
# 29436  Bangalore       72.0
#
# [4319 rows x 2 columns]

# %%
Price=[]
for x in data2["New_price"]:
   x1=x-5
   Price.append(x1)
print(Price)
# Out:
# [60.0, 48.0, 46.6, 115.0, 53.0, 185.0, 125.0, 80.0, 73.5, 79.0, 145.0, 53.0, 155.0, 29.5, 85.0, 75.0, 53.0, 67.0, 105.0, 43.0, 155.0, 93.0, 105.0, 80.0, 255.0, 60.0, 55.7, 100.0, 95.0, 84.5, 103.0, 81.5, 31.0, 75.0, 66.0, 255.0, 57.0, 475.0, 51.0, 105.0, 100.0, 55.0, 32.0, 99.0, 90.0, 45.0, 345.0, 90.0, 61.0, 54.0, 43.0, 37.4, 175.0, 39.0, 36.0, 83.6, 50.0, 115.0, 31.0, 475.0, 99.0, 79.0, 115.0, 65.0, 51.8, 50.0, 32.0, 101.0, 245.0, 63.0, 355.0, 325.0, 50.0, 285.0, 485.0, 105.0, 75.0, 305.0, 30.299999999999997, 49.5, 405.0, 104.0, 115.0, 42.0, 97.0, 675.0, 92.0, 145.0, 50.7, 56.0, 100.0, 80.0, 102.6, 83.0, 81.0, 80.0, 51.0, 295.0, 115.0, 50.0, 65.0, 135.0, 74.9, 275.0, 385.0, 56.0, 38.5, 125.0, 71.0, 88.0, 53.0, 48.0, 105.0, 92.5, 125.0, 69.5, 65.0, 98.0, 45.0, 93.0, 70.0, 100.0, 58.0, 33.1, 105.0, 145.0, 90.0, 185.0, 115.0, 80.0, 40.0, 50.0, 84.0, 104.0, 40.0, 115.0, 115.0, 65.0, 40.0, 60.0, 86.0, 73.0, 165.0, 85.0, 145.0, 135.0, 44.0, 92.0, 84.0, 155.0, 81.0, 105.0, 100.0, 23.0, 90
# ...

# %%
data2.insert(1,"Price",Price)

# %%
del data2["New_price"]

# %%
data2
# Out:
#             City  Price
# 0      Bangalore   60.0
# 2      Bangalore   48.0
# 8      Bangalore   46.6
# 11     Bangalore  115.0
# 12     Bangalore   53.0
# ...          ...    ...
# 29408  Bangalore   47.0
# 29415  Bangalore  225.0
# 29421  Bangalore  102.0
# 29433  Bangalore   55.0
# 29436  Bangalore   67.0
#
# [4319 rows x 2 columns]

# %%
data2["City"].unique()
# Out:
# array(['Bangalore'], dtype=object)

# %%
data2["Price"].unique()
# Out:
# array([6.0000e+01, 4.8000e+01, 4.6600e+01, 1.1500e+02, 5.3000e+01,
#        1.8500e+02, 1.2500e+02, 8.0000e+01, 7.3500e+01, 7.9000e+01,
#        1.4500e+02, 1.5500e+02, 2.9500e+01, 8.5000e+01, 7.5000e+01,
#        6.7000e+01, 1.0500e+02, 4.3000e+01, 9.3000e+01, 2.5500e+02,
#        5.5700e+01, 1.0000e+02, 9.5000e+01, 8.4500e+01, 1.0300e+02,
#        8.1500e+01, 3.1000e+01, 6.6000e+01, 5.7000e+01, 4.7500e+02,
#        5.1000e+01, 5.5000e+01, 3.2000e+01, 9.9000e+01, 9.0000e+01,
#        4.5000e+01, 3.4500e+02, 6.1000e+01, 5.4000e+01, 3.7400e+01,
#        1.7500e+02, 3.9000e+01, 3.6000e+01, 8.3600e+01, 5.0000e+01,
#        6.5000e+01, 5.1800e+01, 1.0100e+02, 2.4500e+02, 6.3000e+01,
#        3.5500e+02, 3.2500e+02, 2.8500e+02, 4.8500e+02, 3.0500e+02,
#        3.0300e+01, 4.9500e+01, 4.0500e+02, 1.0400e+02, 4.2000e+01,
#        9.7000e+01, 6.7500e+02, 9.2000e+01, 5.0700e+01, 5.6000e+01,
#        1.0260e+02, 8.3000e+01, 8.1000e+01, 2.9500e+02, 1.3500e+02,
# ...
